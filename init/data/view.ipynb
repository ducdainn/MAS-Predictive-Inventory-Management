# %%
import pandas as pd

df = pd.read_csv('branch_distance.csv')
df.head()
# Out:
#    branch_code_1  branch_code_2  distance_km
# 0              0              0         0.00
# 1              0              1       606.03
# 2              0              2        58.29
# 3              0              8        11.69
# 4              0             10        26.03

# %%
br = pd.read_csv('branch.csv')

# %%
br.branch_code.value_counts()
# Out:
# branch_code
# 1      1
# 2      1
# 8      1
# 10     1
# 11     1
#       ..
# 121    1
# 122    1
# 123    1
# 120    1
# 80     1
# Name: count, Length: 83, dtype: int64

# %%
df.distance_km.describe()
# Out:
# count    6889.000000
# mean      263.876278
# std       187.751031
# min         0.000000
# 25%       120.250000
# 50%       217.790000
# 75%       377.210000
# max       833.200000
# Name: distance_km, dtype: float64
